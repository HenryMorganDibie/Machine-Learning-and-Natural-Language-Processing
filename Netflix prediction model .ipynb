# %%
# Getting data ready
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import numpy as np


# Import data 
data = pd.read_csv('netflix1.csv')

# Split data
X = data.drop('type', axis=1)
y = data['type']

Netflix.columns

# Turn the categories into numbers
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categorical_features = ['show_id', 'title', 'director', 'country', 'date_added',
       'release_year', 'rating', 'duration', 'listed_in']
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot", 
                                 one_hot, 
                                 categorical_features)],
                                 remainder="passthrough")
transformed_X = transformer.fit_transform(X)
transformed_X

transformed_X[0]

pd.DataFrame(transformed_X)

X.iloc[0]

X_train,y_train
X_test, y_test

# Choose the right estimator/algorithm or models and hyperparamtersfor our problems
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)

# we keep the default hyperparameters
model.get_params()

# Let's refit the model
np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(transformed_X,
                                                    y,
                                                    test_size=0.2)

model.fit(X_train, y_train)
model.score(X_test, y_test)

# Make predictions
y_preds = model.predict(X_test)

# Make predictions with probabilities
y_probs = model.predict_proba(X_test)

y_probs[:10], len(y_probs)

y_probs_positive = y_probs[:, 1]
y_probs_positive[:10]

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(classification_report(y_test, y_preds))

# Improve a model
# Try different amount of n_estimators
np.random.seed(42)
for i in range(10, 100, 10):
    print(f"Trying model with {i} estimators...")
    model = RandomForestClassifier(n_estimators=i).fit(X_train, y_train)
    print(f"Model accuracy on test set: {model.score(X_test, y_test) * 100:.2f}%")
    print("")
# Out:
#               precision    recall  f1-score   support
#
#        Movie       1.00      1.00      1.00      1238
#      TV Show       1.00      0.99      1.00       520
#
#     accuracy                           1.00      1758
#    macro avg       1.00      1.00      1.00      1758
# weighted avg       1.00      1.00      1.00      1758
#
# Trying model with 10 estimators...
# Model accuracy on test set: 99.66%
#
# Trying model with 20 estimators...
# Model accuracy on test set: 99.54%
#
# Trying model with 30 estimators...
# Model accuracy on test set: 99.49%
#
# Trying model with 40 estimators...
# Model accuracy on test set: 99.49%
#
# Trying model with 50 estimators...
# Model accuracy on test set: 99.60%
#
# Trying model with 60 estimators...
# Model accuracy on test set: 99.54%
#
# Trying model with 70 estimators...
# Model accuracy on test set: 99.72%
#
# Trying model with 80 estimators...
# Model accuracy on test set: 99.66%
#
# Trying model with 90 estimators...
# Model accuracy on test set: 99.49%
